# %%
value= input("enter any integer: ")
print (value)
print(type(value))
print(id(value))
# Out:
# 56
# <class 'str'>
# 2659737011328

# %%
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
print(num1+num2,type(num1+num2))
# Out:
# 30 <class 'int'>

# %%
num1=float(input("enter first number:"))
num2=float(input("enter second number:"))
print(num1+num2,type(num1+num2))
# Out:
# 21.4 <class 'float'>

# %%
num1=int(input("enter first number:"))
num2=float(input("enter second number:"))
print(num1+num2,type(num1+num2))
# Out:
# 2.2 <class 'float'>

# %%
num1=int(input("enter first number:"))
num2=float(input("enter second number:"))
num3=complex(input("enter third number:"))
print(num1+num2+num3,type(num1+num2+num3))
# Out:
# (6+8j) <class 'complex'>
