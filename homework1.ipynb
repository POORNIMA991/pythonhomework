# %%
city = 'New York'
print(city)
# Out:
# New York

# %%
city = 'delhi'
print(city)
print(type(city))
print(id(city))
# Out:
# delhi
# <class 'str'>
# 1409418724240

# %%
ans= True
print (ans)
print(type(ans))
print(id(ans))
# Out:
# True
# <class 'bool'>
# 140736611756800
