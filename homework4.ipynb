# %%
city="delhi"
print(delhi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 city="delhi"
# ----> 2 print(delhi)
#
# NameError: name 'delhi' is not defined
