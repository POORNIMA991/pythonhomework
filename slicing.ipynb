# %%
s1="Poornima"
print(s1[:6:1])
print(s1[:4:1])
print(s1[6::1])
print(s1[0::1])
print(s1[3:6:1])
print(s1[:7:1])
print(s1[::-1])
print(s1[3:len(s1):1]) 
print(s1[len(s1):3:-1])         ###slicing with negative step
print(s1[len(s1):6:-1])
print(s1[len(s1):8:-1])          ### string limit exceeded
print(s1[len(s1):1:-1])
print(s1[-1:3:-1])
print(s1[-5:-1:1])
print(s1[-2:3:-1])
print(s1[:3:1])
print(s1[4:8:1])
print(s1[-1:-9:-1])
# Out:
# Poorni
# Poor
# ma
# Poornima
# rni
# Poornim
# aminrooP
# rnima
# amin
# a
#
# aminro
# amin
# rnim
# min
# Poo
# nima
# aminrooP
