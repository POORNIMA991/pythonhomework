# %% [markdown]
# ### INDEXING AND SLICING

# %%
s= "INSTAGRAM"
print(s[3],s[5],s[-5],s[-4])
# Out:
# T G A G

# %% [markdown]
# ### FORWARD slicing

# %%
s1="Python Programming"
print(s1[0],s1[17])
# Out:
# P g

# %% [markdown]
# ### BACKWARD slicing

# %%
s1="Python Programming"
print(s1[-18],s1[-1])
# Out:
# P g

# %% [markdown]
# ### forward indexing

# %%
s1="Python Programming"
print(s1[0])
print(s1[17])
# Out:
# P
# g

# %% [markdown]
# ### backward indexing

# %%
s1="Python Programming"
print(s1[-18])
print(s1[-1])
# Out:
# P
# g

# %%
s1="Python Programming"
print(s1[0],s1[17],s1[-18],s1[-1])
# Out:
# P g P g
